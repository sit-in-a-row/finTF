# %%
# 2020 Q2부터 시작할 수 있음..

# high_list = [
#     "4. 재무제표.csv",
#     "2. 연결재무제표.csv",
#     "1. 요약재무정보.csv",
#     "5. 재무제표 주석.csv",
#     "3. 연결재무제표 주석.csv",
#     "6. 배당에 관한 사항 등.csv",
#     "3. 자본금 변동사항.csv",
#     "VII. 주주에 관한 사항.csv",
#     "IX. 계열회사 등에 관한 사항.csv",
#     "XI. 그 밖에 투자자 보호를 위하여 필요한 사항.csv",
#     "III. 재무에 관한 사항.csv",
# ]
# medium_list = [
#     "4. 주식의 총수 등.csv",
#     "5. 의결권 현황.csv",
#     "1. 이사회에 관한 사항.csv",
#     "VI. 이사회 등 회사의 기관에 관한 사항.csv",
#     "IV. 이사의 경영진단 및 분석의견.csv",
#     "2. 임원의 보수 등.csv",
# ]

high_list = [
    "1. 요약재무정보.csv",
    "2. 연결재무제표.csv",
    "3. 연결재무제표 주석.csv",
    "4. 재무제표.csv",
    "5. 재무제표 주석.csv",
    "3. 자본금 변동사항.csv",
    "6. 배당에 관한 사항 등.csv",
    "IV. 이사의 경영진단 및 분석의견.csv",
]

medium_list = [
"VII. 주주에 관한 사항.csv",
"IX. 계열회사 등에 관한 사항.csv",
"XI. 그 밖에 투자자 보호를 위하여 필요한 사항.csv",


]

#  주주현황, 계열사, 투자자 보호 관련 추가공시, 이사회/임원/의결권 현황 등

###
summary_system = "당신은 금융 전문가입니다. 주어진 금융 보고서 각각에 대해, step-by-step으로 요약하세요."

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import nltk
nltk.download('punkt')

model_dir = "lcw99/t5-base-korean-text-summary"
tokenizer = AutoTokenizer.from_pretrained(model_dir)
model = AutoModelForSeq2SeqLM.from_pretrained(model_dir)

max_input_length = 2048

import ast
import os

from sub_func import fin_statement_info # ticker, year, quarter -> df
from sub_func import reports_info # ticker, year, quarter -> df
from sub_func import corp_rel_news_info # ticker, year, start_date, end_date -> df
from sub_func import intl_news_info # year, start_date, end_date -> df
from sub_func import macro_econ_info # year, start_date, end_date -> dict
from sub_func import stock_price_info # ticker, start_date, end_date -> df
from sub_func import index_price_info # sector, start_date, end_date -> df
from sub_func import pattern_info # ticker, date -> df
from sub_func import sector_analysis_info # sector, year, quarter -> dict

from sub_func import get_index_list

from sub_func import to_GPT

from sub_func import preprocess_financial_text

def price_estimation_info():
    return None 

def current_portfolio_info():
    return None

def portfolio_analysis_info():
    return None

# ================================================================================================================ #

def get_ordered_report_dict(ticker, year, quarter):
    """
    중요도에 따라 보고서를 분류한 dict 반환
    """

    df = reports_info(ticker, year, quarter)
    report_importance_dict = {
        'High': {},
        'Medium': {}
    }

    csv_list = list(df.keys())
    for csv in csv_list:
        if csv in high_list:
            report_importance_dict['High'][csv] = ast.literal_eval(df[csv][0])[0]
        elif csv in medium_list:
            report_importance_dict['Medium'][csv] = ast.literal_eval(df[csv][0])[0]
        else:
            pass

    return report_importance_dict

def summarize_text(text):
    """
    금융 관련 문장 요약 모델
    """
    inputs = ["summarize: " + f"{preprocess_financial_text(text)}"]

    inputs = tokenizer(inputs, max_length=max_input_length, truncation=False, return_tensors="pt")
    output = model.generate(**inputs, num_beams=8, do_sample=True, min_length=10, max_length=300)
    decoded_output = tokenizer.batch_decode(output, skip_special_tokens=True)[0]
    result = nltk.sent_tokenize(decoded_output.strip())[0]

    return result

def sliding_window_summary(text, max_chunk_len=1000, overlap_len=100):
    """
    긴 텍스트를 분할해 요약하고 결과를 재결합
    """
    # 텍스트 분할
    sentences = nltk.sent_tokenize(text)
    chunks = []
    current_chunk = []

    # 슬라이딩 윈도우 방식으로 분할
    for sentence in sentences:
        if len(" ".join(current_chunk + [sentence])) <= max_chunk_len:
            current_chunk.append(sentence)
        else:
            chunks.append(" ".join(current_chunk))
            current_chunk = sentences[
                max(0, len(current_chunk) - overlap_len):]  # 중첩된 부분 유지

    if current_chunk:
        chunks.append(" ".join(current_chunk))

    # 요약 결과 생성
    summaries = [summarize_text(chunk) for chunk in chunks]
    final_summary = " ".join(summaries)
    
    return final_summary
# Out:
# [nltk_data] Downloading package punkt to /Users/yeonsuk/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /opt/anaconda3/envs/finTF/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
# ====================================================================================================================== #
TODAY = '20200630'
target_year = '2020'
target_quarter = 'Q2'

quarter_list = ['Q1', 'Q2', 'Q3', 'Q4']

fin_statement_dict = {}
fin_report_dict = {}
corp_rel_news_dict = {}
intl_news_dict = {}
macro_econ_dict = {}
corp_price_dict = {}
index_price_dict = {}
pattern_dict = {}
sector_analysis_dict = {}

# ====================================================================================================================== #

# r_{portfolio manager_{t_5}1}도 불러와야함 | 일단 패스

# ====================================================================================================================== #

# 한 분기 이전 정보 찾기 (ex. 만약 지금이 Q3라면 Q2의 정보를 가져와야 함. 만약 Q1이라면 이전 년도의 Q4를 가져와야 함.)
if target_quarter == 'Q1':
    target_year = f"{int(target_year)-1}"

search_quarter_idx = (quarter_list.index(target_quarter) - 1) % 4
search_quarter = quarter_list[search_quarter_idx]

if search_quarter == 'Q1':
    start_date = target_year + '0101'
    # end_date = target_year + '0331'
    end_date = TODAY
elif search_quarter == 'Q2':
    start_date = target_year + '0401'
    # end_date = target_year + '0630'
    end_date = TODAY
elif search_quarter == 'Q3':
    start_date = target_year + '0701'
    # end_date = target_year + '0930'
    end_date = TODAY
elif search_quarter == 'Q4':
    start_date = target_year + '1001'
    # end_date = target_year + '1231'
    end_date = TODAY

### ====== 티커 필요 없는 항목들 가져오기 ====== ###
# ==== 거시경제 정보 가져오기 ==== #
macro_econ = macro_econ_info(target_year, start_date, end_date)
macro_econ_dict[target_year] = macro_econ

# ==== 국제 뉴스 가져오기 ==== #
intl_news = intl_news_info(target_year, start_date, end_date)
intl_news_dict[f"{start_date}_{end_date}"] = intl_news

# ==== 인덱스 가격 가져오기 ==== #
index_list = get_index_list()
for index in index_list:
    try:
        idx_price = index_price_info(index, start_date, end_date)
        index_price_dict[index] = idx_price

        sector_analysis = sector_analysis_info(index, target_year, search_quarter)
        sector_analysis_dict[index] = sector_analysis
    except:
        continue

# ====================================================================================================================== #

### ====== 티커 기반 항목들 가져오기 ====== ###
tickers_list = os.listdir('../store_data/raw/market_data/price/')
for i in range(len(tickers_list)):

    try:
        target_ticker = tickers_list[i]

        #  ==== 재무제표 분석 정보 가져와서 담아두기 ==== #
        fin_statement = fin_statement_info(target_ticker, target_year, search_quarter)
        fin_statement_dict[target_ticker] = fin_statement

        # ==== 재무보고서 가져와서 담아두기 ==== #
        fin_report = get_ordered_report_dict(target_ticker, target_year, search_quarter)
        report_txt = ""
        for report in fin_report['Medium']:
            report_txt += f"{preprocess_financial_text(fin_report['Medium'][report])}"
        
        # GPT 기반 요약?
        # response = to_GPT(summary_system, report_txt)['choices'][0]['message']['content']
        response = report_txt

        fin_report['Medium'] = ''
        fin_report['Medium'] = response
        fin_report_dict[target_ticker] = fin_report

        # ==== 뉴스 정보 가져오기 ==== #
        corp_rel_news = corp_rel_news_info(target_ticker, target_year, start_date, end_date)
        corp_rel_news_dict[target_ticker] = corp_rel_news

        # ==== 가격 정보 가져오기 ==== #
        corp_price = stock_price_info(target_ticker, start_date, end_date)
        corp_price_dict[target_ticker] = corp_price

        # # ==== 차트 패턴 정보 가져오기 ==== #
        # pattern = pattern_info(target_ticker, end_date)
        # pattern_dict[target_ticker] = pattern

    except:
        continue
# Out:
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/013700/_013700_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/013700/_013700_재무제표 ().csv'
# 013700의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 013700의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/058860'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/058860'
# 058860의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 058860의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/005830/_005830_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/005830/_005830_재무제표 ().csv'
# 005830의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 005830의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/014710/_014710_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/014710/_014710_재무제표 ().csv'
# 014710의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 014710의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/027390'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/027390'
# 027390의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 027390의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/101140'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/101140'
# 101140의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 101140의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001200/_001200_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001200/_001200_재무제표 ().csv'
# 001200의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 001200의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/159650/_159650_재무제표 ().csv'
# 2020의 159650 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/159650/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/012280'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/012280'
# 012280의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 012280의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/306200'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/306200'
# 306200의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 306200의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/140910'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/140910'
# 140910의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 140910의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/338100'
# 2020의 338100 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/338100/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/338100'
# 338100의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 338100의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/000140/_000140_재무제표 ().csv'
# 000140의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 000140의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/264900'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/264900'
# 264900의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 264900의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/004380/_004380_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/004380/_004380_재무제표 ().csv'
# 004380의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 004380의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/003535'
# 2020의 003535 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/003535/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/003535'
# 003535의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 003535의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/039490/_039490_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/039490/_039490_재무제표 ().csv'
# 039490의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 039490의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/099350'
# 2020의 099350 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/099350/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/099350'
# 099350의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 099350의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/33626L'
# 2020의 33626L 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/33626L/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/33626L'
# 33626L의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 33626L의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001450/_001450_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001450/_001450_재무제표 ().csv'
# 001450의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 001450의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/004310'
# 2020의 004310 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/004310/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/004310'
# 004310의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 004310의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/272450'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/272450'
# 272450의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 272450의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/025890'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/025890'
# 025890의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 025890의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/33626K'
# 2020의 33626K 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/33626K/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/33626K'
# 33626K의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 33626K의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/068400/_068400_재무제표 ().csv'
# 068400의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 068400의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/006220/_006220_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/006220/_006220_재무제표 ().csv'
# 006220의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 006220의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/016610/_016610_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/016610/_016610_재무제표 ().csv'
# 016610의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 016610의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/002210'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/002210'
# 002210의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 002210의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/000547'
# 2020의 000547 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/000547/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/000547'
# 000547의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 000547의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/000540'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/000540'
# 000540의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 000540의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/002025'
# 2020의 002025 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/002025/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/002025'
# 002025의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 002025의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/005690'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/005690'
# 005690의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 005690의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/096775'
# 2020의 096775 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/096775/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/096775'
# 096775의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 096775의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/084680'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/084680'
# 084680의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 084680의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/204210/_204210_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/204210/_204210_재무제표 ().csv'
# 204210의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 204210의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001290/_001290_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001290/_001290_재무제표 ().csv'
# 001290의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 001290의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/009835'
# 2020의 009835 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/009835/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/009835'
# 009835의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 009835의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/133820/_133820_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/133820/_133820_재무제표 ().csv'
# 133820의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 133820의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001067'
# 2020의 001067 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/001067/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001067'
# 001067의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 001067의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/034830/_034830_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/034830/_034830_재무제표 ().csv'
# 034830의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 034830의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/134380'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/134380'
# 134380의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 134380의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/071050/_071050_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/071050/_071050_재무제표 ().csv'
# 071050의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 071050의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/003470/_003470_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/003470/_003470_재무제표 ().csv'
# 003470의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 003470의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/005745'
# 2020의 005745 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/005745/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/005745'
# 005745의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 005745의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/33637K'
# 2020의 33637K 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/33637K/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/33637K'
# 33637K의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 33637K의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/003680/_003680_재무제표 ().csv'
# 003680의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 003680의 fin_statement_info 정보를 확인할 수 없습니다.
# /Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/market_data/price/.DS_Store/2020.01/2020.01_.DS_Store.csv 파일을 찾을 수 없습니다.
# /Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/market_data/price/.DS_Store/2020.02/2020.02_.DS_Store.csv 파일을 찾을 수 없습니다.
# /Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/market_data/price/.DS_Store/2020.03/2020.03_.DS_Store.csv 파일을 찾을 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 20] Not a directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/.DS_Store'
# 2020의 .DS_Store 발행 주식수 파일을 읽는 중 오류 발생: [Errno 20] Not a directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/.DS_Store/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 20] Not a directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/.DS_Store'
# .DS_Store의 이전 년도 재무 데이터를 불러올 수 없습니다.
# .DS_Store의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/004200'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/004200'
# 004200의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 004200의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/33637L'
# 2020의 33637L 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/33637L/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/33637L'
# 33637L의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 33637L의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/085620/_085620_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/085620/_085620_재무제표 ().csv'
# 085620의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 085620의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/003415'
# 2020의 003415 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/003415/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/003415'
# 003415의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 003415의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/063160/_063160_재무제표 ().csv'
# 063160의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 063160의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/090355'
# 2020의 090355 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/090355/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/090355'
# 090355의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 090355의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/00806K'
# 2020의 00806K 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/00806K/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/00806K'
# 00806K의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 00806K의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/007280'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/007280'
# 007280의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 007280의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/019175'
# 2020의 019175 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/019175/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/019175'
# 019175의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 019175의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/006390'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/006390'
# 006390의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 006390의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001525'
# 2020의 001525 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/001525/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001525'
# 001525의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 001525의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/009770/_009770_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/000060/_000060_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/000060/_000060_재무제표 ().csv'
# 000060의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 000060의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/088350/_088350_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/088350/_088350_재무제표 ().csv'
# 088350의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 088350의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/083380'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/083380'
# 083380의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 083380의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/168490'
# 2020의 168490 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/168490/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/168490'
# 168490의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 168490의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/120115'
# 2020의 120115 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/120115/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/120115'
# 120115의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 120115의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/004450/_004450_재무제표 ().csv'
# 004450의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 004450의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/010050/_010050_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/010050/_010050_재무제표 ().csv'
# 010050의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 010050의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001780/_001780_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/008260'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/008260'
# 008260의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 008260의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001745'
# 2020의 001745 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/001745/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001745'
# 001745의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 001745의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/316140/_316140_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/316140/_316140_재무제표 ().csv'
# 316140의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 316140의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/078520/_078520_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/152550'
# 2020의 152550 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/152550/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/152550'
# 152550의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 152550의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/003610/_003610_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/005389'
# 2020의 005389 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/005389/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/005389'
# 005389의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 005389의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/051630'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/051630'
# 051630의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 051630의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/002355'
# 2020의 002355 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/002355/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/002355'
# 002355의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 002355의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/005945'
# 2020의 005945 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/005945/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/005945'
# 005945의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 005945의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/214390'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/214390'
# 214390의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 214390의 fin_statement_info 정보를 확인할 수 없습니다.
# 005380의 이전 년도 순이익 데이터를 찾을 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001720/_001720_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001720/_001720_재무제표 ().csv'
# 001720의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 001720의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/002700'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/002700'
# 002700의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 002700의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/18064K'
# 2020의 18064K 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/18064K/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/18064K'
# 18064K의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 18064K의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/152330'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/152330'
# 152330의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 152330의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/004255'
# 2020의 004255 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/004255/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/004255'
# 004255의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 004255의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/005387'
# 2020의 005387 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/005387/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/005387'
# 005387의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 005387의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/003070/_003070_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001515'
# 2020의 001515 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/001515/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001515'
# 001515의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 001515의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/000075'
# 2020의 000075 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/000075/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/000075'
# 000075의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 000075의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/082640/_082640_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/082640/_082640_재무제표 ().csv'
# 082640의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 082640의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/088980'
# 2020의 088980 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/088980/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/088980'
# 088980의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 088980의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/005500/_005500_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/005500/_005500_재무제표 ().csv'
# 005500의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 005500의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/033250/_033250_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/000885'
# 2020의 000885 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/000885/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/000885'
# 000885의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 000885의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/004410'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/004410'
# 004410의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 004410의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/023000'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/023000'
# 023000의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 023000의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/109070/_109070_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/294870/_294870_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/000225'
# 2020의 000225 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/000225/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/000225'
# 000225의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 000225의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/010420/_010420_재무제표 ().csv'
# ...
# 002690의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 002690의 fin_statement_info 정보를 확인할 수 없습니다.
# 순이익 데이터를 찾을 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/105560/_105560_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/105560/_105560_재무제표 ().csv'
# 105560의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 105560의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/012690'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/012690'
# 012690의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 012690의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/004365'
# 2020의 004365 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/004365/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/004365'
# 004365의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 004365의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/090435'
# 2020의 090435 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/090435/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/090435'
# 090435의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 090435의 fin_statement_info 정보를 확인할 수 없습니다.
# 003720의 이전 년도 순이익 데이터를 찾을 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001880/_001880_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001880/_001880_재무제표 ().csv'
# 001880의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 001880의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/123890/_123890_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/123890/_123890_재무제표 ().csv'
# 123890의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 123890의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/025820'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/025820'
# 025820의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 025820의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/096300'
# 2020의 096300 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/096300/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/096300'
# 096300의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 096300의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/019685'
# 2020의 019685 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/019685/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/019685'
# 019685의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 019685의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/034300/_034300_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/034300/_034300_재무제표 ().csv'
# 034300의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 034300의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/004105'
# 2020의 004105 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/004105/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/004105'
# 004105의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 004105의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/006800/_006800_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/006800/_006800_재무제표 ().csv'
# 006800의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 006800의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/031820/_031820_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/031820/_031820_재무제표 ().csv'
# 031820의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 031820의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/272210/_272210_재무제표 ().csv'
# 272210의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 272210의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/003547'
# 2020의 003547 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/003547/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/003547'
# 003547의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 003547의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/055550/_055550_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/055550/_055550_재무제표 ().csv'
# 055550의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 055550의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/014160'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/014160'
# 014160의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 014160의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/003540/_003540_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/003540/_003540_재무제표 ().csv'
# 003540의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 003540의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/000157'
# 2020의 000157 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/000157/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/000157'
# 000157의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 000157의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/002600/_002600_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/002600/_002600_재무제표 ().csv'
# 002600의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 002600의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/004990/_004990_재무제표 ().csv'
# 004990의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 004990의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/006405'
# 2020의 006405 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/006405/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/006405'
# 006405의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 006405의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/088260/_088260_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/088260/_088260_재무제표 ().csv'
# 088260의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 088260의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/004700'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/004700'
# 004700의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 004700의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/037710'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/037710'
# 037710의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 037710의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/005070'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/005070'
# 005070의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 005070의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/021820/_021820_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/021820/_021820_재무제표 ().csv'
# 021820의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 021820의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/016800/_016800_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/016800/_016800_재무제표 ().csv'
# 016800의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 016800의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/300720/_300720_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/300720/_300720_재무제표 ().csv'
# 300720의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 300720의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001275'
# 2020의 001275 발행 주식수 파일을 읽는 중 오류 발생: [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_reports/001275/2020.03'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/001275'
# 001275의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 001275의 fin_statement_info 정보를 확인할 수 없습니다.
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/044820/_044820_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/086790/_086790_재무제표 ().csv'
# 재무제표를 불러오는 과정에서 오류가 발생했습니다 | [Errno 2] No such file or directory: '/Users/yeonsuk/investment/finTF/pipeline/sub_func/../../store_data/raw/opendart/store_financial_statement/086790/_086790_재무제표 ().csv'
# 086790의 이전 년도 재무 데이터를 불러올 수 없습니다.
# 086790의 fin_statement_info 정보를 확인할 수 없습니다.

# %%
fin_statement_dict
fin_report_dict
corp_rel_news_dict
corp_price_dict
pattern_dict

index_price_dict
sector_analysis_dict

intl_news_dict
macro_econ_dict
# Out:
#    start_date    end_date          pattern      prob
# 0  2019-01-17  2019-04-30  ascending_wedge  0.987465

# %%
sample_dict = {
    'fin_statement': fin_statement_dict['005930'],
    'fin_report': fin_report_dict['005930'],
    'corp_rel_news': corp_rel_news_dict['005930'],
    'corp_price': corp_price_dict['005930'],
    # 'pattern': pattern_dict['005930'],

    'index_price': index_price_dict,
    'sector_analysis': sector_analysis_dict,

    'intl_news': intl_news_dict,
    'macro_econ': macro_econ_dict
}

# %%
for key, value in sample_dict.items():
    print(f"Key: {key}, Type: {type(value)}")

import pandas as pd

def convert_to_serializable(obj):
    if isinstance(obj, pd.DataFrame):
        return obj.to_dict(orient="records")
    elif isinstance(obj, dict):
        return {k: convert_to_serializable(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [convert_to_serializable(v) for v in obj]
    else:
        return obj



sample_dict_serializable = convert_to_serializable(sample_dict)

with open("data.json", "w", encoding="utf-8") as f:
    json.dump(sample_dict_serializable, f, ensure_ascii=False, indent=4)
# Out:
# Key: fin_statement, Type: <class 'list'>
# Key: fin_report, Type: <class 'dict'>
# Key: corp_rel_news, Type: <class 'list'>
# Key: corp_price, Type: <class 'list'>
# Key: index_price, Type: <class 'dict'>
# Key: sector_analysis, Type: <class 'dict'>
# Key: intl_news, Type: <class 'dict'>
# Key: macro_econ, Type: <class 'dict'>

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/yeonsuk/investment/finTF/store_data/raw/opendart/store_reports/000020/2020.09/000020_분기보고서 (2020.09) | 1. 요약재무정보.csv')

# %%
list(df['text'])[0].split('\\n')
# Out:
# ["['",
#  '1. 요약재무정보',
#  '가. 요약 연결재무정보',
#  '\\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 (단위 : 천원)',
#  '\\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0\\xa0 사업연도과\\xa0\\xa0 목',
#  '92기 (2020.09.30)',
#  '91기 (2019.12.31)',
#  '90기 (2018.12.31)',
#  '[유동자산]',
#  '245,994,161\\xa0',
#  '\\xa0235,456,988\\xa0',
#  '227,887,463\\xa0',
#  '\\xa0 현금및현금성자산',
#  '72,397,341\\xa0',
#  '\\xa037,779,183\\xa0',
#  '40,614,515\\xa0',
#  '\\xa0 기타금융자산',
#  '64,420,087\\xa0',
#  '\\xa0 \\xa0 82,949,068\\xa0',
#  '63,444,817\\xa0',
#  '\\xa0 매출채권및기타채권',
#  '68,897,028\\xa0',
#  '\\xa0 \\xa0 79,441,839\\xa0',
#  '79,057,839\\xa0',
#  '\\xa0 재고자산',
#  '38,957,552\\xa0',
#  '\\xa0 \\xa0 33,430,792\\xa0',
#  '43,717,602\\xa0',
#  '\\xa0 기타유동자산',
#  '1,208,990\\xa0',
#  '\\xa0 \\xa0 \\xa0 1,855,585\\xa0',
#  '1,052,691\\xa0',
#  '\\xa0 당기법인세자산',
#  '113,163\\xa0',
#  '\\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 521\\xa0',
#  '0',
#  '[비유동자산]',
#  '178,567,380\\xa0',
#  '\\xa0\\xa0 140,571,565\\xa0',
#  '142,711,780\\xa0',
#  '\\xa0 공정가치측정금융자산',
#  '26,427,372\\xa0',
#  '\\xa0 \\xa0 17,070,195\\xa0',
#  '13,740,748\\xa0',
#  '\\xa0 관계기업투자주식',
#  '6,272,031\\xa0',
#  '0',
#  '9,886,572\\xa0',
#  '\\xa0 기타금융자산',
#  '16,155,150\\xa0',
#  '\\xa0 \\xa0 13,169,517\\xa0',
#  '12,872,438\\xa0',
#  '\\xa0 유형자산',
#  '101,241,466\\xa0',
#  '\\xa0 \\xa0 92,308,557\\xa0',
#  '96,772,495\\xa0',
#  '\\xa0 무형자산',
#  '14,017,925\\xa0',
#  '\\xa0 \\xa0 \\xa0 5,464,653\\xa0',
#  '5,581,169\\xa0',
#  '\\xa0 사용권자산',
#  '6,293,059\\xa0',
#  '\\xa0 \\xa0 \\xa0 6,906,243\\xa0',
#  '0\\xa0',
#  '\\xa0 투자부동산\\xa0',
#  '3,699,874\\xa0',
#  '0',
#  '0\\xa0',
#  '\\xa0 이연법인세자산',
#  '4,460,503\\xa0',
#  '\\xa0 \\xa0 \\xa0 5,652,400\\xa0',
#  '3,858,358\\xa0',
#  '자산총계',
#  '424,561,541\\xa0',
#  '\\xa0\\xa0 376,028,553\\xa0',
#  '370,599,243\\xa0',
#  '[유동부채]',
#  '68,594,823\\xa0',
#  '\\xa055,714,627\\xa0',
#  '60,798,281',
#  '[비유동부채]',
#  '23,698,167\\xa0',
#  '\\xa019,439,332\\xa0',
#  '12,400,310',
#  '부채총계',
#  '92,292,990\\xa0',
#  '\\xa075,153,959\\xa0',
#  '73,198,591',
#  '[소유주지분]',
#  '325,600,010\\xa0',
#  '\\xa0\\xa0 300,874,594\\xa0',
#  '\\xa0 \\xa0 \\xa0 \\xa0 \\xa0 297,091,045\\xa0',
#  '\\xa0 자본금',
#  '27,931,470\\xa0',
#  '\\xa0 \\xa0 27,931,470\\xa0',
#  '\\xa0 \\xa0 \\xa0 \\xa0 \\xa0\\xa0 27,931,470\\xa0',
#  '\\xa0 자본잉여금',
#  '27,069,235\\xa0',
#  '\\xa0 \\xa0 27,069,235\\xa0',
#  '\\xa0 \\xa0 \\xa0 \\xa0 \\xa0\\xa0 27,069,235\\xa0',
#  '\\xa0 자기주식',
#  '(2,521,454)\\xa0',
#  '(2,521,454)\\xa0',
#  '\\xa0\\xa0 (2,521,454)',
#  '\\xa0 기타포괄손익누계액',
#  '8,965,634\\xa0',
#  '\\xa0 \\xa0 \\xa0 1,667,041\\xa0',
#  '\\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0\\xa0 1,464,725\\xa0',
#  '\\xa0 이익잉여금',
#  '264,155,125\\xa0',
#  '\\xa0\\xa0 246,728,302\\xa0',
#  '\\xa0 \\xa0 \\xa0 \\xa0 \\xa0 243,147,069\\xa0',
#  '\\xa0[비재배지분]',
#  '6,668,541\\xa0',
#  '0',
#  '\\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0\\xa0 309,606\\xa0',
#  '자본총계',
#  '332,268,551\\xa0',
#  '\\xa0\\xa0 300,874,594\\xa0',
#  '\\xa0 \\xa0 \\xa0 \\xa0 \\xa0 297,400,652\\xa0',
#  '\\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 사업연도과\\xa0\\xa0 목',
#  '92기 (2020.01.01~2020.09.30)',
#  '91기 (2019.01.01~2019.12.31)',
#  '90기(2018.01.01~2018.12.31)',
#  '매출액',
#  '203,405,176\\xa0',
#  '\\xa0307,150,026\\xa0',
#  '306,602,589',
#  '영업이익',
#  '16,127,229\\xa0',
#  '\\xa09,917,746\\xa0',
#  '11,225,780',
#  '법인세비용차감전순이익',
#  '\\xa026,190,467\\xa0',
#  '\\xa016,607,868\\xa0',
#  '14,539,062',
#  '당기순이익',
#  '20,733,784\\xa0',
#  '\\xa09,393,855\\xa0',
#  '10,068,113',
#  '\\xa0지배기업의 소유주지분',
#  '20,739,751\\xa0',
#  '9,402,231\\xa0',
#  '10,068,506',
#  '\\xa0비지배지분',
#  '(5,967)\\xa0',
#  '(8,376)',
#  '(393)',
#  '총포괄손익',
#  '28,032,376\\xa0',
#  '7,088,100',
#  '4,821,848',
#  '\\xa0지배기업의 소유주지분',
#  '28,038,343\\xa0',
#  '7,096,477\\xa0',
#  '4,822,241',
#  '\\xa0비지배지분',
#  '(5,967)\\xa0',
#  '(8,376)',
#  '(393)',
#  '주당손익',
#  '\\xa0 기본주당순손익(원)',
#  '751\\xa0',
#  '341',
#  '365',
#  '연결에 포함된 회사 수',
#  '2\\xa0',
#  '1',
#  '1',
#  '* 주식회사 메디쎄이는 9월 말 연결실체에 포함되어 손익은 포함되어 있지 않습니다.나. 요약별도 재무정보',
#  '\\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 (단위 : 천원)',
#  '\\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0\\xa0 사업연도과\\xa0\\xa0 목',
#  '92기(2020.09.30)',
#  '91기(2019.12.31)',
#  '90기 (2018.12.31)',
#  '[유동자산]',
#  '228,485,791\\xa0',
#  '\\xa0\\xa0 235,349,683\\xa0',
#  '\\xa0\\xa0 226,382,731\\xa0',
#  '\\xa0 현금및현금성자산',
#  '64,933,182\\xa0',
#  '\\xa0 \\xa0 37,729,876\\xa0',
#  '\\xa0 \\xa0 39,729,885\\xa0',
#  '\\xa0 기타금융자산',
#  '64,417,329\\xa0',
#  '\\xa0 \\xa0 82,949,068\\xa0',
#  '\\xa0 \\xa0 63,444,817\\xa0',
#  '\\xa0 매출채권및기타채권',
#  '62,599,897\\xa0',
#  '\\xa0 \\xa0 79,441,839\\xa0',
#  '\\xa0 \\xa0 78,557,838\\xa0',
#  '\\xa0 재고자산',
#  '35,551,529\\xa0',
#  '\\xa0 \\xa0 33,430,792\\xa0',
#  '\\xa0 \\xa0 43,717,603\\xa0',
#  '\\xa0 기타유동자산',
#  '983,854\\xa0',
#  '\\xa0 \\xa0 \\xa0 1,798,108\\xa0',
#  '\\xa0 \\xa0 \\xa0 \\xa0 932,589\\xa0',
#  '[비유동자산]',
#  '175,839,320\\xa0',
#  '\\xa0\\xa0 141,116,406\\xa0',
#  '\\xa0\\xa0 143,911,768\\xa0',
#  '\\xa0 공정가치측정금융자산',
#  '22,443,095\\xa0',
#  '\\xa0 \\xa0 13,085,918\\xa0',
#  '\\xa0 \\xa0 10,240,737\\xa0',
#  '\\xa0 관계기업투자주식',
#  '3,616,500\\xa0',
#  '0\\xa0',
#  '\\xa0 \\xa0 \\xa0 9,886,572\\xa0',
#  '\\xa0 종속기업투자주식',
#  '26,681,345\\xa0',
#  '4,700,000\\xa0',
#  '4,700,000\\xa0',
#  '\\xa0 기타금융자산',
#  '16,063,440\\xa0',
#  '\\xa0 \\xa0 13,169,517\\xa0',
#  '\\xa0 \\xa0 12,872,438\\xa0',
#  '\\xa0 유형자산',
#  '92,135,366\\xa0',
#  '\\xa0 \\xa0 92,308,557\\xa0',
#  '\\xa0 \\xa0 96,772,495\\xa0',
#  '\\xa0 무형자산',
#  '4,880,080\\xa0',
#  '\\xa0 \\xa0 \\xa0 5,464,653\\xa0',
#  '\\xa0 \\xa0 \\xa0 5,581,169\\xa0',
#  '\\xa0 사용권자산',
#  '6,039,422\\xa0',
#  '\\xa0 \\xa0 \\xa0 6,906,243\\xa0',
#  '0\\xa0',
#  '\\xa0 이연법인세자산',
#  '3,980,071\\xa0',
#  '\\xa0 \\xa0 \\xa0 5,481,518\\xa0',
#  '\\xa0 \\xa0 \\xa0 3,858,358\\xa0',
#  '자산총계',
#  '404,325,111\\xa0',
#  '\\xa0\\xa0 376,466,089\\xa0',
#  '\\xa0\\xa0 370,294,499\\xa0',
#  '[유동부채]',
#  '54,677,188\\xa0',
#  '\\xa055,714,627\\xa0',
#  '60,797,176\\xa0',
#  '[비유동부채]',
#  '23,218,715\\xa0',
#  '\\xa019,138,102\\xa0',
#  '12,400,309\\xa0',
#  '부채총계',
#  '77,895,903\\xa0',
#  '\\xa074,852,729\\xa0',
#  '73,197,485\\xa0',
#  '\\xa0 자본금',
#  '27,931,470\\xa0',
#  '27,931,470\\xa0',
#  '27,931,470\\xa0',
#  '\\xa0 자본잉여금',
#  '27,069,235\\xa0',
#  '27,069,235\\xa0',
#  '27,069,234\\xa0',
#  '\\xa0 자기주식',
#  '(2,521,454)\\xa0',
#  '(2,521,454)',
#  '(2,521,454)\\xa0',
#  '\\xa0 기타포괄손익누계액',
#  '9,571,486\\xa0',
#  '2,272,893\\xa0',
#  '1,464,725\\xa0',
#  '\\xa0 이익잉여금',
#  '264,378,471\\xa0',
#  '246,861,215\\xa0',
#  '243,153,038\\xa0',
#  '자본총계',
#  '326,429,208\\xa0',
#  '301,613,360\\xa0',
#  '297,097,013\\xa0',
#  '종속·관계·공동기업 투자주식의 평가방법',
#  '원가법지분법',
#  '원가법지분법',
#  '원가법지분법',
#  '\\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 \\xa0 사업연도과\\xa0\\xa0 목',
#  '92기 (2020.01.01~2020.09.30)',
#  '91기 (2019.01.01~2019.12.31)',
#  '90기(2018.01.01~2018.12.31)',
#  '매출액',
#  '203,405,176\\xa0',
#  '307,150,026\\xa0',
#  '306,602,589',
#  '영업이익',
#  '16,223,654\\xa0',
#  '10,056,453\\xa0',
#  '11,232,142',
#  '법인세비용차감전순이익',
#  '26,286,866\\xa0',
#  '16,743,189\\xa0',
#  '14,545,424',
#  '당기순이익',
#  '20,830,183\\xa0',
#  '9,529,176\\xa0',
#  '10,074,475',
#  '총포괄손익',
#  '28,128,775\\xa0',
#  '7,829,274\\xa0',
#  '4,828,209',
#  '주당손익',
#  '\\xa0 기본주당순손익(원)',
#  '755\\xa0',
#  '345',
#  '365',
#  "']"]
